# %%
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler, StandardScaler, RobustScaler, MaxAbsScaler

# %%
np.random.seed(42)
data = np.random.randint(0, 100, size=(100, 4))
df = pd.DataFrame(data, columns=['Feature1', 'Feature2', 'Feature3', 'Feature4'])
df['Feature5'] = np.random.randint(0, 1000, size=(100,))

df.head()
# Out:
#    Feature1  Feature2  Feature3  Feature4  Feature5
# 0        51        92        14        71       961
# 1        60        20        82        86       638
# 2        74        74        87        99       154
# 3        23         2        21        52       489
# 4         1        87        29        37       385

# %%
df
# Out:
#     Feature1  Feature2  Feature3  Feature4  Feature5
# 0         51        92        14        71       961
# 1         60        20        82        86       638
# 2         74        74        87        99       154
# 3         23         2        21        52       489
# 4          1        87        29        37       385
# ..       ...       ...       ...       ...       ...
# 95        59        96        62        84       950
# 96        31        86        32        66       345
# 97        17        24        94        53       740
# 98        57        66        45        23       473
# 99        31        46        85        22       116
#
# [100 rows x 5 columns]

# %%
min_max_scaler = MinMaxScaler()
df.min_max_scaler = pd.DataFrame(min_max_scaler.fit_transform(df), columns = df.columns)
# Out:
# <ipython-input-4-a0a463f483e6>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.min_max_scaler = pd.DataFrame(min_max_scaler.fit_transform(df), columns = df.columns)

# %%
standard_scalar = StandardScaler()
df.standard_scalar = pd.DataFrame(standard_scalar.fit_transform(df), columns = df.columns)
# Out:
# <ipython-input-5-abaf242f04e8>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.standard_scalar = pd.DataFrame(standard_scalar.fit_transform(df), columns = df.columns)

# %%
robust_scaler = RobustScaler()
df.robust_scaler = pd.DataFrame(robust_scaler.fit_transform(df), columns = df.columns)
# Out:
# <ipython-input-6-955de249efdf>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.robust_scaler = pd.DataFrame(robust_scaler.fit_transform(df), columns = df.columns)

# %%
max_abs_scaler = MaxAbsScaler()
df.max_abs_scaler = pd.DataFrame(max_abs_scaler.fit_transform(df), columns = df.columns)
# Out:
# <ipython-input-7-8ccabc5168ef>:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.max_abs_scaler = pd.DataFrame(max_abs_scaler.fit_transform(df), columns = df.columns)

# %%
print("\nMin-Max-Scaler: \n", df.min_max_scaler.head())
print("\nStandard-Scaler: \n", df.standard_scalar.head())
print("\nRobust-Scaler: \n", df.robust_scaler.head())
print("\nMax-Abs-Scaler: \n", df.max_abs_scaler.head())
# Out:
# Min-Max-Scaler:
#     Feature1  Feature2  Feature3  Feature4  Feature5
# 0  0.520408  0.928571  0.142857  0.714286  0.968623
# 1  0.612245  0.193878  0.836735  0.867347  0.641700
# 2  0.755102  0.744898  0.887755  1.000000  0.151822
# 3  0.234694  0.010204  0.214286  0.520408  0.490891
# 4  0.010204  0.877551  0.295918  0.367347  0.385628
#
# Standard-Scaler:
#     Feature1  Feature2  Feature3  Feature4  Feature5
# 0  0.090471  1.393878 -1.083404  0.611371  1.402362
# 1  0.386558 -1.039663  1.295398  1.122835  0.329753
# 2  0.847137  0.785493  1.470309  1.566104 -1.277501
# 3 -0.830688 -1.648048 -0.838528 -0.036484 -0.165042
# 4 -1.554455  1.224882 -0.558669 -0.547949 -0.510403
#
# Robust-Scaler:
#     Feature1  Feature2  Feature3  Feature4  Feature5
# 0  0.009346  0.848485 -0.719512  0.318841  0.684083
# 1  0.177570 -0.606061  0.939024  0.608696  0.059023
# 2  0.439252  0.484848  1.060976  0.859903 -0.877600
# 3 -0.514019 -0.969697 -0.548780 -0.048309 -0.229318
# ...
