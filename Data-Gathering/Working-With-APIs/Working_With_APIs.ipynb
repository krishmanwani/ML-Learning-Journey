# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')
#It makes a request to the API using the API key given to every user by TMDB

# %%
temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
#It selects specific rows from the data after converting it to json file

# %%
temp_df.head()
# Out:
#     id                     title  \
# 0  278  The Shawshank Redemption
# 1  238             The Godfather
# 2  240     The Godfather Part II
# 3  424          Schindler's List
# 4  389              12 Angry Men
#
#                                             overview release_date  popularity  \
# 0  Imprisoned in the 1940s for the double murder ...   1994-09-23     186.490
# 1  Spanning the years 1945 to 1955, a chronicle o...   1972-03-14     163.489
# 2  In the continuing saga of the Corleone crime f...   1974-12-20     110.816
# 3  The true story of how businessman Oskar Schind...   1993-12-15     111.670
# 4  The defense and the prosecution have rested an...   1957-04-10      62.663
#
#    vote_average  vote_count
# 0         8.709       27591
# 1         8.689       20936
# 2         8.571       12631
# 3         8.600       16077
# 4         8.548        8821

# %%
df = pd.DataFrame() #Creates a empty dataframe

# %%
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

#The database have total 428 pages, so every page is called one by one and the data is concated together to get the final data

# %%
df
# Out:
#           id                     title  \
# 0        278  The Shawshank Redemption
# 1        238             The Godfather
# 2        240     The Godfather Part II
# 3        424          Schindler's List
# 4        389              12 Angry Men
# ...      ...                       ...
# 8555  429202                   Vox Lux
# 8556   11519                      1941
# 8557    8869       Eight Legged Freaks
# 8558  485942              Batman Ninja
# 8559  377264                    Morgan
#
#                                                overview release_date  \
# 0     Imprisoned in the 1940s for the double murder ...   1994-09-23
# 1     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     The defense and the prosecution have rested an...   1957-04-10
# ...                                                 ...          ...
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
#Converts the json file to csv
