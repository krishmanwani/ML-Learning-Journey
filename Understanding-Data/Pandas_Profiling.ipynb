# %%
import pandas as pd

# %%
df = pd.read_csv("/content/train.csv")

# %%
from ydata_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# The overview in the output does the initial steps of understanding the data.
#
#
# ---
#
#
# In Warnings:
#
# High-cardinality means it is a categorical data with high number of categories.
#
#
# ---
#
#
# Variables does the uni-variate analysis.
#
#
# ---
#
#
# Interactions, Correlations does the bi-variate analysis
#
#
# ---
#
#
# Missing Values given the count of missing values in every column.
#
#
# ---
#
#
# Sample shows the first and last 10 rows of the dataset ot get the idea of the dataset.
